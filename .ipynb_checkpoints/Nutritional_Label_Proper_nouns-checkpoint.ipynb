# %%
import glob

from auditor import *

# %%
treatment_names = ['change_gender', 'change_race', 'change_gender_and_race']

# Define the score_names (target labels) and the primary key between control, treatments and demographic information
score_names = ['Score']
primary_key = 'ID'

# %%
demographic_df = pd.read_csv("text_demographic_info.csv")
demographic_df.shape
# Out:
# (641, 4)

# %%
demographic_df
# Out:
#      Unnamed: 0   ID     Text_length Sentiment_polarity
# 0             0  345  medium 100-500    Pretty negative
# 1             1  346  medium 100-500            Neutral
# 2             2  347  medium 100-500    Pretty negative
# 3             3  348       long >500    Pretty positive
# 4             4  349  medium 100-500    Pretty positive
# ..          ...  ...             ...                ...
# 636         636   56       long >500    Pretty positive
# 637         637   57  medium 100-500            Neutral
# 638         638   58  medium 100-500    Pretty negative
# 639         639   59      short <100    Pretty positive
# 640         640   60  medium 100-500            Neutral
#
# [641 rows x 4 columns]

# %%
groups_of_interest ={"Text_length":['long >500', 'short <100'],
                     "Sentiment_polarity":['Pretty positive', 'Pretty negative']}

# %%
FilenamesList = glob.glob('Data_with_names_scored*.csv')
FilenamesList
# Out:
# ['Data_with_names_scored4.csv',
#  'Data_with_names_scored5.csv',
#  'Data_with_names_scored7.csv',
#  'Data_with_names_scored6.csv',
#  'Data_with_names_scored2.csv',
#  'Data_with_names_scored3.csv',
#  'Data_with_names_scored.csv']

# %%
res_df = pd.read_csv(FilenamesList[0])
for f in FilenamesList[1:]:
    res_df = res_df.append(pd.read_csv(f))
    
res_df.shape
# Out:
# (1428, 6)

# %%
res_i = res_df.index.values
demo_i = demographic_df['Unnamed: 0'].values

ID_list = list(set.intersection(set(res_i), set(demo_i) ))

# %%
res_df = res_df.loc[ID_list]
demographic_df = demographic_df.loc[ID_list]

# %%
control_scores = res_df[['Unnamed: 0', 'Greg_score']]
control_scores.rename(columns={'Unnamed: 0': 'ID', 'Greg_score': 'Score'}, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
col_names = ['Emily_score', 'Jamal_score', 'Lakisha_score']

# %%
treatment_scores = {}

# %%
for i in range(len(treatment_names)):
    temp = res_df[['Unnamed: 0', col_names[i]]]
    temp.rename(columns={'Unnamed: 0': 'ID', col_names[i]: 'Score'}, inplace=True)
    treatment_scores[treatment_names[i]] = temp

# %%
perspective_audit = Auditor(score_names, primary_key, control_scores, 
                          treatment_scores, demographic_df, groups_of_interest)

# %%
perspective_audit.visualize_scores(axislim=1)

# %%
tv = perspective_audit.compute_total_variation()

# %%
perspective_audit.visualize_total_variation()

# %%
def get_corr_results(perspective_audit, test, test_name, cutoff_low, cutoff_high):
    low = test_name+" >"+str(cutoff_low)
    high = test_name+" >"+str(cutoff_high)
    
    spearman_ = perspective_audit.compute_statistic(test=test)
    spearman_corr = spearman_.loc[[i for i in spearman_.index if 'correlation' in i]]
    spearman_corr.rename(columns={'Score':test_name}, inplace=True)

    spearman_corr[low] = [i>cutoff_low for i in spearman_corr[test_name].values]
    spearman_corr[high] = [i>cutoff_high for i in spearman_corr[test_name].values]
    return spearman_corr

# %%
spearman_res = get_corr_results(perspective_audit, spearman, "spearman", 0.9, 0.95)
pearsons_res = get_corr_results(perspective_audit, pearsons, "pearsons", 0.9, 0.95)
kendall_tau_res = get_corr_results(perspective_audit, kendall_tau, "kendall_tau", 0.9, 0.95)

# %%
correlation_tests = pd.concat([spearman_res, pearsons_res, kendall_tau_res], axis=1)
correlation_tests
# Out:
#                                                                        spearman  \
# change_gender          overall__                          correlation  0.945535
#                        Text_length_long >500              correlation  0.944190
#                        Text_length_short <100             correlation  0.945665
#                        Text_length_others                 correlation  0.946606
#                        Sentiment_polarity_Pretty positive correlation  0.944516
#                        Sentiment_polarity_Pretty negative correlation  0.947226
#                        Sentiment_polarity_others          correlation  0.947861
# change_race            overall__                          correlation  0.959266
#                        Text_length_long >500              correlation  0.956008
#                        Text_length_short <100             correlation  0.961934
#                        Text_length_others                 correlation  0.958979
#                        Sentiment_polarity_Pretty positive correlation  0.957530
#                        Sentiment_polarity_Pretty negative correlation  0.960418
#                        Sentiment_polarity_others          correlation  0.963060
# change_gender_and_race overall__                          correlation  0.975640
#                        Text_length_long >500              correlation  0.974700
#                        Text_length_short <100             correlation  0.977430
#                        Text_length_others                 correlation  0.974687
#                        Sentiment_polarity_Pretty positive correlation  0.973200
#                        Sentiment_polarity_Pretty negative correlation  0.981540
#                        Sentiment_polarity_others          correlation  0.976130
#
#                                                                        spearman >0.9  \
# change_gender          overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
# change_race            overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
# change_gender_and_race overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
#
#                                                                        spearman >0.95  \
# change_gender          overall__                          correlation           False
#                        Text_length_long >500              correlation           False
#                        Text_length_short <100             correlation           False
#                        Text_length_others                 correlation           False
#                        Sentiment_polarity_Pretty positive correlation           False
#                        Sentiment_polarity_Pretty negative correlation           False
#                        Sentiment_polarity_others          correlation           False
# change_race            overall__                          correlation            True
#                        Text_length_long >500              correlation            True
#                        Text_length_short <100             correlation            True
#                        Text_length_others                 correlation            True
#                        Sentiment_polarity_Pretty positive correlation            True
#                        Sentiment_polarity_Pretty negative correlation            True
#                        Sentiment_polarity_others          correlation            True
# change_gender_and_race overall__                          correlation            True
#                        Text_length_long >500              correlation            True
#                        Text_length_short <100             correlation            True
#                        Text_length_others                 correlation            True
#                        Sentiment_polarity_Pretty positive correlation            True
#                        Sentiment_polarity_Pretty negative correlation            True
#                        Sentiment_polarity_others          correlation            True
#
#                                                                        pearsons  \
# change_gender          overall__                          correlation  0.994401
#                        Text_length_long >500              correlation  0.994459
#                        Text_length_short <100             correlation  0.994598
#                        Text_length_others                 correlation  0.994227
#                        Sentiment_polarity_Pretty positive correlation  0.995026
#                        Sentiment_polarity_Pretty negative correlation  0.992918
#                        Sentiment_polarity_others          correlation  0.994238
# change_race            overall__                          correlation  0.996745
#                        Text_length_long >500              correlation  0.995835
#                        Text_length_short <100             correlation  0.997400
#                        Text_length_others                 correlation  0.996746
#                        Sentiment_polarity_Pretty positive correlation  0.996790
#                        Sentiment_polarity_Pretty negative correlation  0.996408
#                        Sentiment_polarity_others          correlation  0.996919
# change_gender_and_race overall__                          correlation  0.991879
#                        Text_length_long >500              correlation  0.995841
#                        Text_length_short <100             correlation  0.993933
#                        Text_length_others                 correlation  0.988427
#                        Sentiment_polarity_Pretty positive correlation  0.991326
#                        Sentiment_polarity_Pretty negative correlation  0.991679
#                        Sentiment_polarity_others          correlation  0.993235
#
#                                                                        pearsons >0.9  \
# change_gender          overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
# change_race            overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
# change_gender_and_race overall__                          correlation           True
#                        Text_length_long >500              correlation           True
#                        Text_length_short <100             correlation           True
#                        Text_length_others                 correlation           True
#                        Sentiment_polarity_Pretty positive correlation           True
#                        Sentiment_polarity_Pretty negative correlation           True
#                        Sentiment_polarity_others          correlation           True
#
#                                                                        pearsons >0.95  \
# change_gender          overall__                          correlation            True
#                        Text_length_long >500              correlation            True
#                        Text_length_short <100             correlation            True
#                        Text_length_others                 correlation            True
#                        Sentiment_polarity_Pretty positive correlation            True
#                        Sentiment_polarity_Pretty negative correlation            True
#                        Sentiment_polarity_others          correlation            True
# change_race            overall__                          correlation            True
#                        Text_length_long >500              correlation            True
#                        Text_length_short <100             correlation            True
#                        Text_length_others                 correlation            True
#                        Sentiment_polarity_Pretty positive correlation            True
#                        Sentiment_polarity_Pretty negative correlation            True
#                        Sentiment_polarity_others          correlation            True
# change_gender_and_race overall__                          correlation            True
#                        Text_length_long >500              correlation            True
#                        Text_length_short <100             correlation            True
#                        Text_length_others                 correlation            True
#                        Sentiment_polarity_Pretty positive correlation            True
#                        Sentiment_polarity_Pretty negative correlation            True
#                        Sentiment_polarity_others          correlation            True
#
#                                                                        kendall_tau  \
# change_gender          overall__                          correlation     0.840910
#                        Text_length_long >500              correlation     0.840823
#                        Text_length_short <100             correlation     0.841535
#                        Text_length_others                 correlation     0.842040
#                        Sentiment_polarity_Pretty positive correlation     0.840774
#                        Sentiment_polarity_Pretty negative correlation     0.840986
#                        Sentiment_polarity_others          correlation     0.844262
# change_race            overall__                          correlation     0.859809
#                        Text_length_long >500              correlation     0.861206
#                        Text_length_short <100             correlation     0.862239
#                        Text_length_others                 correlation     0.858452
#                        Sentiment_polarity_Pretty positive correlation     0.858638
#                        Sentiment_polarity_Pretty negative correlation     0.858776
#                        Sentiment_polarity_others          correlation     0.867035
# change_gender_and_race overall__                          correlation     0.899792
#                        Text_length_long >500              correlation     0.903513
#                        Text_length_short <100             correlation     0.900524
#                        Text_length_others                 correlation     0.898949
#                        Sentiment_polarity_Pretty positive correlation     0.899018
#                        Sentiment_polarity_Pretty negative correlation     0.903213
#                        Sentiment_polarity_others          correlation     0.901526
#
#                                                                        kendall_tau >0.9  \
# change_gender          overall__                          correlation             False
#                        Text_length_long >500              correlation             False
#                        Text_length_short <100             correlation             False
#                        Text_length_others                 correlation             False
#                        Sentiment_polarity_Pretty positive correlation             False
#                        Sentiment_polarity_Pretty negative correlation             False
#                        Sentiment_polarity_others          correlation             False
# change_race            overall__                          correlation             False
#                        Text_length_long >500              correlation             False
#                        Text_length_short <100             correlation             False
#                        Text_length_others                 correlation             False
#                        Sentiment_polarity_Pretty positive correlation             False
#                        Sentiment_polarity_Pretty negative correlation             False
#                        Sentiment_polarity_others          correlation             False
# change_gender_and_race overall__                          correlation             False
#                        Text_length_long >500              correlation              True
#                        Text_length_short <100             correlation              True
#                        Text_length_others                 correlation             False
#                        Sentiment_polarity_Pretty positive correlation             False
#                        Sentiment_polarity_Pretty negative correlation              True
#                        Sentiment_polarity_others          correlation              True
#
#                                                                        kendall_tau >0.95
# change_gender          overall__                          correlation              False
#                        Text_length_long >500              correlation              False
#                        Text_length_short <100             correlation              False
#                        Text_length_others                 correlation              False
#                        Sentiment_polarity_Pretty positive correlation              False
#                        Sentiment_polarity_Pretty negative correlation              False
#                        Sentiment_polarity_others          correlation              False
# change_race            overall__                          correlation              False
#                        Text_length_long >500              correlation              False
#                        Text_length_short <100             correlation              False
#                        Text_length_others                 correlation              False
#                        Sentiment_polarity_Pretty positive correlation              False
#                        Sentiment_polarity_Pretty negative correlation              False
#                        Sentiment_polarity_others          correlation              False
# change_gender_and_race overall__                          correlation              False
#                        Text_length_long >500              correlation              False
#                        Text_length_short <100             correlation              False
#                        Text_length_others                 correlation              False
#                        Sentiment_polarity_Pretty positive correlation              False
#                        Sentiment_polarity_Pretty negative correlation              False
#                        Sentiment_polarity_others          correlation              False

# %%
def test_statistic_results(perspective_audit, test, test_name, correction, alpha_threshold):
    test_ = perspective_audit.compute_statistic(test=test)
    pvals = test_.loc[[i for i in test_.index if 'p_value' in i]]
    corrected = perspective_audit.multiple_hypothesis_correction(pvals, alpha = alpha_threshold, method=correction)
    res = corrected[perspective_audit.score_names] > alpha_threshold
    res.rename(columns={'Score':test_name}, inplace=True)
    return res

# %%
wilcoxon_res = test_statistic_results(perspective_audit, wilcoxon, "wilcoxon", 'fdr_bh', 0.05)
student_t_res = test_statistic_results(perspective_audit, student_t, "student_t", 'fdr_bh', 0.05)
paired_student_t_res = test_statistic_results(perspective_audit, paired_student_t, "paired_student_t", 'fdr_bh', 0.05)
mann_whitney_u_res = test_statistic_results(perspective_audit, mann_whitney_u, "mann_whitney_u", 'fdr_bh', 0.05)
kruskal_wallis_h = test_statistic_results(perspective_audit, kruskal_wallis_h, "kruskal_wallis_h", 'fdr_bh', 0.05)

# %%
statistical_tests = pd.concat([wilcoxon_res, student_t_res, paired_student_t_res, mann_whitney_u_res, kruskal_wallis_h], axis=1)
statistical_tests
# Out:
#                                                                    wilcoxon  \
# change_gender          overall__                          p_value     False
#                        Text_length_long >500              p_value     False
#                        Text_length_short <100             p_value     False
#                        Text_length_others                 p_value     False
#                        Sentiment_polarity_Pretty positive p_value     False
#                        Sentiment_polarity_Pretty negative p_value     False
#                        Sentiment_polarity_others          p_value     False
# change_race            overall__                          p_value     False
#                        Text_length_long >500              p_value     False
#                        Text_length_short <100             p_value     False
#                        Text_length_others                 p_value     False
#                        Sentiment_polarity_Pretty positive p_value     False
#                        Sentiment_polarity_Pretty negative p_value     False
#                        Sentiment_polarity_others          p_value     False
# change_gender_and_race overall__                          p_value     False
#                        Text_length_long >500              p_value     False
#                        Text_length_short <100             p_value     False
#                        Text_length_others                 p_value     False
#                        Sentiment_polarity_Pretty positive p_value     False
#                        Sentiment_polarity_Pretty negative p_value     False
#                        Sentiment_polarity_others          p_value     False
#
#                                                                    student_t  \
# change_gender          overall__                          p_value       True
#                        Text_length_long >500              p_value       True
#                        Text_length_short <100             p_value       True
#                        Text_length_others                 p_value       True
#                        Sentiment_polarity_Pretty positive p_value       True
#                        Sentiment_polarity_Pretty negative p_value       True
#                        Sentiment_polarity_others          p_value       True
# change_race            overall__                          p_value       True
#                        Text_length_long >500              p_value       True
#                        Text_length_short <100             p_value       True
#                        Text_length_others                 p_value       True
#                        Sentiment_polarity_Pretty positive p_value       True
#                        Sentiment_polarity_Pretty negative p_value       True
#                        Sentiment_polarity_others          p_value       True
# change_gender_and_race overall__                          p_value       True
#                        Text_length_long >500              p_value       True
#                        Text_length_short <100             p_value       True
#                        Text_length_others                 p_value       True
#                        Sentiment_polarity_Pretty positive p_value       True
#                        Sentiment_polarity_Pretty negative p_value       True
#                        Sentiment_polarity_others          p_value       True
#
#                                                                    paired_student_t  \
# change_gender          overall__                          p_value             False
#                        Text_length_long >500              p_value             False
#                        Text_length_short <100             p_value             False
#                        Text_length_others                 p_value             False
#                        Sentiment_polarity_Pretty positive p_value             False
#                        Sentiment_polarity_Pretty negative p_value             False
#                        Sentiment_polarity_others          p_value             False
# change_race            overall__                          p_value             False
#                        Text_length_long >500              p_value             False
#                        Text_length_short <100             p_value             False
#                        Text_length_others                 p_value             False
#                        Sentiment_polarity_Pretty positive p_value             False
#                        Sentiment_polarity_Pretty negative p_value             False
#                        Sentiment_polarity_others          p_value             False
# change_gender_and_race overall__                          p_value             False
#                        Text_length_long >500              p_value             False
#                        Text_length_short <100             p_value             False
#                        Text_length_others                 p_value             False
#                        Sentiment_polarity_Pretty positive p_value             False
#                        Sentiment_polarity_Pretty negative p_value             False
#                        Sentiment_polarity_others          p_value             False
#
#                                                                    mann_whitney_u  \
# change_gender          overall__                          p_value            True
#                        Text_length_long >500              p_value            True
#                        Text_length_short <100             p_value            True
#                        Text_length_others                 p_value            True
#                        Sentiment_polarity_Pretty positive p_value            True
#                        Sentiment_polarity_Pretty negative p_value            True
#                        Sentiment_polarity_others          p_value            True
# change_race            overall__                          p_value           False
#                        Text_length_long >500              p_value            True
#                        Text_length_short <100             p_value            True
#                        Text_length_others                 p_value           False
#                        Sentiment_polarity_Pretty positive p_value           False
#                        Sentiment_polarity_Pretty negative p_value            True
#                        Sentiment_polarity_others          p_value            True
# change_gender_and_race overall__                          p_value            True
#                        Text_length_long >500              p_value            True
#                        Text_length_short <100             p_value            True
#                        Text_length_others                 p_value            True
#                        Sentiment_polarity_Pretty positive p_value            True
#                        Sentiment_polarity_Pretty negative p_value            True
#                        Sentiment_polarity_others          p_value            True
#
#                                                                    kruskal_wallis_h
# change_gender          overall__                          p_value              True
#                        Text_length_long >500              p_value              True
#                        Text_length_short <100             p_value              True
#                        Text_length_others                 p_value              True
#                        Sentiment_polarity_Pretty positive p_value              True
#                        Sentiment_polarity_Pretty negative p_value              True
#                        Sentiment_polarity_others          p_value              True
# change_race            overall__                          p_value             False
#                        Text_length_long >500              p_value              True
#                        Text_length_short <100             p_value              True
#                        Text_length_others                 p_value             False
#                        Sentiment_polarity_Pretty positive p_value             False
#                        Sentiment_polarity_Pretty negative p_value              True
#                        Sentiment_polarity_others          p_value              True
# change_gender_and_race overall__                          p_value              True
#                        Text_length_long >500              p_value              True
#                        Text_length_short <100             p_value              True
#                        Text_length_others                 p_value              True
#                        Sentiment_polarity_Pretty positive p_value              True
#                        Sentiment_polarity_Pretty negative p_value              True
#                        Sentiment_polarity_others          p_value              True
